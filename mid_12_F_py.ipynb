# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachanon19/12-Rachnaon-F/blob/main/mid_12_F_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
light  = int(input("ระดับความเข้มของแสง(%) : "))


if light < 20:
    print("พืชกำลังผลิตอาหาร")

else:
    print("พืชหยุดผลิดอาหาร")
# Out:
# ระดับความเข้มของแสง(%) : 21
# พืชหยุดผลิดอาหาร
